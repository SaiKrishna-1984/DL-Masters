# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv(r"https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
#         year      name   percent   sex
# 0       1880  John      0.081541  boy
# 1       1880  William   0.080511  boy
# 2       1880  James     0.050057  boy
# 3       1880  Charles   0.045167  boy
# 4       1880  George    0.043292  boy
# ...      ...     ...         ...  ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008  Iyana     0.000128  girl
# 257997  2008  Kenley    0.000127  girl
# 257998  2008  Sloane    0.000127  girl
# 257999  2008  Elianna   0.000127  girl
#
# [258000 rows x 4 columns]

# %% [markdown]
# Questions

# %% [markdown]
# ## 1. Delete unnamed columns
#    ###  There are no un-named columns.

# %%
df[df.name == ' ']
# Out:
# Empty DataFrame
# Columns: [year, name, percent, sex]
# Index: []

# %% [markdown]
# ## 2. Show the distribution of male and female

# %%
print(df['sex'].value_counts())
print("-"*30)
print(df['sex'].describe())
# Out:
# boy     129000
# girl    129000
# Name: sex, dtype: int64
# ------------------------------
# count     258000
# unique         2
# top          boy
# freq      129000
# Name: sex, dtype: object

# %% [markdown]
# ## 3. Show the top 5 most preferred names
#
# pandas.Series.value_counts
# - Series.value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
# - Return a Series containing counts of unique values.
# - The resulting object will be in descending order so that the first element is the most frequently-occurring element.
# - Excludes NA values by default.

# %%
df["name"].value_counts()[0:5]
# Out:
# Jessie       258
# Leslie       247
# Guadalupe    244
# Jean         244
# Lee          240
# Name: name, dtype: int64

# %% [markdown]
# ## 4. What is the median name occurence in the dataset

# %%
df["name"].value_counts().median()
# Out:
# 19.0

# %% [markdown]
# ## 5. Distribution of male and female born count by states

# %%
data = df.drop(['year', 'name'], axis = 1)
data['counts'] = df['sex']

# %%
pd.pivot_table(data, index= ['percent','sex'],  aggfunc='count', fill_value = 0).head(25)
# Out:
#                counts
# percent  sex
# 0.000026 boy       22
# 0.000027 boy      173
# 0.000028 boy      300
# 0.000029 boy      387
# 0.000030 boy      400
# 0.000031 boy      420
# 0.000032 boy      442
# 0.000033 boy      433
# 0.000034 boy      390
# 0.000035 boy      445
# 0.000036 boy      452
# 0.000037 boy      453
# 0.000038 boy      435
# 0.000039 boy      440
#          girl       8
# 0.000040 boy      446
#          girl      62
# 0.000041 boy      583
#          girl      58
# 0.000042 boy      735
#          girl     255
# 0.000043 boy      692
#          girl     113
# 0.000044 boy      806
#          girl     320

# %%
df[['percent','sex']][df.sex == 'boy'].groupby('percent').count().head(20)
# Out:
#           sex
# percent
# 0.000026   22
# 0.000027  173
# 0.000028  300
# 0.000029  387
# 0.000030  400
# 0.000031  420
# 0.000032  442
# 0.000033  433
# 0.000034  390
# 0.000035  445
# 0.000036  452
# 0.000037  453
# 0.000038  435
# 0.000039  440
# 0.000040  446
# 0.000041  583
# 0.000042  735
# 0.000043  692
# 0.000044  806
# 0.000045  777

# %%
df[['percent','sex']][df.sex == 'girl'].groupby('percent').count().head(5)
# Out:
#           sex
# percent
# 0.000039    8
# 0.000040   62
# 0.000041   58
# 0.000042  255
# 0.000043  113

# %%
import seaborn as sns
plt.figure(figsize=(20, 10))
sns.countplot(x="percent", hue="sex", data=df)
# Out:
# <AxesSubplot:xlabel='percent', ylabel='count'>

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
months   = np.arange(1,13)

plt.plot(months, temp_max, 'r+')
plt.plot(months, temp_min, 'bo')
plt.xlabel('Months')
plt.ylabel('Min and Max Temperature')
# Out:
# Text(0, 0.5, 'Min and Max Temperature')

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = pd.DataFrame(resp.json())
data.head()
# Out:
#                                                            url                                  repository_url                                                                 labels_url                                                          comments_url                                                          events_url                                           html_url         id                           node_id  number                                                                   title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
df = pd.read_json(url)
df.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
list(df.loc[2]['user'].values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4409             try:
# -> 4410                 return libindex.get_value_at(s, key)
#    4411             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-aa67c484a5cd> in <module>
# ----> 1 list(df.loc[2]['user'].values())
#
# ...

# %%
list(df.loc[2]['user'])
# Out:
# ['login',
#  'id',
#  'node_id',
#  'avatar_url',
#  'gravatar_id',
#  'url',
#  'html_url',
#  'followers_url',
#  'following_url',
#  'gists_url',
#  'starred_url',
#  'subscriptions_url',
#  'organizations_url',
#  'repos_url',
#  'events_url',
#  'received_events_url',
#  'type',
#  'site_admin']

# %%
df.loc[2]['user']
# Out:
# {'login': 'ylin00',
#  'id': 18493550,
#  'node_id': 'MDQ6VXNlcjE4NDkzNTUw',
#  'avatar_url': 'https://avatars0.githubusercontent.com/u/18493550?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/ylin00',
#  'html_url': 'https://github.com/ylin00',
#  'followers_url': 'https://api.github.com/users/ylin00/followers',
#  'following_url': 'https://api.github.com/users/ylin00/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/ylin00/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/ylin00/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/ylin00/subscriptions',
#  'organizations_url': 'https://api.github.com/users/ylin00/orgs',
#  'repos_url': 'https://api.github.com/users/ylin00/repos',
#  'events_url': 'https://api.github.com/users/ylin00/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/ylin00/received_events',
#  'type': 'User',
#  'site_admin': False}
